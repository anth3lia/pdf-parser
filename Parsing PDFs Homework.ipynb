# %% [markdown]
# # Parsing PDFs Homework
#
# With the power of pdfminer, pytesseract, Camelot, and Tika, let's analyze some documents!
#
# > If at any point you think, **"I'm close enough, I'd just edit the rest of it in Excel"**: that's fine! Just make a note of it.
#
# ## A trick to use again and again
#
# ### Approach 1
#
# Before we get started: when you want to take the first row of your data and set it as the header, use this trick.

# %%
import pandas as pd
df = pd.DataFrame([
    [ 'fruit name', 'likes' ],
    [ 'apple', 15 ],
    [ 'carrot', 3 ],
    [ 'sweet potato', 45 ],
    [ 'peach', 12 ],
])
df
# Out:
#               0      1
# 0    fruit name  likes
# 1         apple     15
# 2        carrot      3
# 3  sweet potato     45
# 4         peach     12

# %%
# Set the first column as the columns
df.columns = df.loc[0]

# Drop the first row
df = df.drop(0)

df
# Out:
# 0    fruit name likes
# 1         apple    15
# 2        carrot     3
# 3  sweet potato    45
# 4         peach    12

# %% [markdown]
# 🚀 Done!
#
# ### Approach 2
#
# Another alternative is to use `.rename` on your columns and just filter out the columns you aren't interested in. This can be useful if the column name shows up multiple times in your data for some reason or another.

# %%
# Starting with the same-ish data...
df = pd.DataFrame([
    [ 'fruit name', 'likes' ],
    [ 'apple', 15 ],
    [ 'carrot', 3 ],
    [ 'fruit name', 'likes' ],
    [ 'sweet potato', 45 ],
    [ 'peach', 12 ],
])
df
# Out:
#               0      1
# 0    fruit name  likes
# 1         apple     15
# 2        carrot      3
# 3    fruit name  likes
# 4  sweet potato     45
# 5         peach     12

# %%
df = df.rename(columns={
    0: 'fruit name',
    1: 'likes'
})
df = df[df['fruit name'] != 'fruit name']
df
# Out:
#      fruit name likes
# 1         apple    15
# 2        carrot     3
# 4  sweet potato    45
# 5         peach    12

# %% [markdown]
# 🚀 Done!
#
# ### Useful tips about coordinates
#
# If you want to grab only a section of the page [Kull](https://jsoma.github.io/kull/#/) might be helpful in finding the coordinates.
#
# > **Alternatively** run `%matplotlib notebook` in a cell. Afterwards, every time you use something like `camelot.plot(tables[0]).show()` it will get you nice zoomable, hoverable versions that include `x` and `y` coordinates as you move your mouse.
#
# Coordinates are given as `"left_x,top_y,right_x,bottom_y"` with `(0,0)` being in the bottom left-hand corner.
#
# Note that all coordinates are strings, for some reason. It won't be `[1, 2, 3, 4]` it will be `['1,2,3,4']`
#
# # The homework
#
# This is **mostly Camelot work**, because I don't really have any good image-based PDFs to stretch your wings on tesseract. If you know of any, let me know and I can put together another couple exercises.
#
# ## Prison Inmates
#
# Working from [InmateList.pdf](InmateList.pdf), save a CSV file that includes every inmate.
#
# * Make sure your rows are *all data*, and you don't have any people named "Inmate Name."

# %%
import tika
from tika import parser

# %%
inmates = parser.from_file('InmateList.pdf')
inmates_df = pd.DataFrame(columns=inmates['content'].strip().split('\n')[0].split(' '))
inmates_df = inmates_df.drop(columns=['#','Name','Date'])
inmates_df = inmates_df.rename(columns={'ICN': 'ICN #', 'Inmate': 'Inmate Name', 'Booking': 'Booking Date'})
inmates_df
# Out:
# Empty DataFrame
# Columns: [ICN #, Inmate Name, Facility, Booking Date]
# Index: []

# %%
inmates_ls = inmates['content'].strip()[87:].split('\n\n')

# %%
inmates_ls
# Out:
# ['70693 ABDALLAH, MICHAEL ECHC 04/30/2021',
#  '152645 ABDI, ABDI ECCF 06/20/2021',
#  '144666 ABDULLAH, DHAFIR ECCF 06/17/2021',
#  '156374 ACEVEDO, CARLOS ECHC 06/06/2021',
#  '57243 ACKER, RAYMOND P ECCF 11/02/2020',
#  '68579 ADAMS, JERMAIN C ECHC 09/19/2019',
#  '45262 ADAMS, MARQUIS ECHC 05/27/2021',
#  '75738 AKRIGHT, JOSEPH A ECCF 05/29/2021',
#  '104048 ALBERTSON, ANDREW ECCF 12/04/2019',
#  '1577 ALEXANDER, BRIAN ECHC 07/13/2021',
#  '148951 ALICEA, PABLO E ECCF 05/19/2020',
#  '139806 ALKULIFI, ABDULLAH ECHC 07/01/2021',
#  '124661 ALLEN, DARNELLE ECCF 12/03/2020',
#  '125234 ALLEN, DEMONDE C ECHC 05/03/2021',
#  '131437 ALLEN, GLENN A ECCF 06/12/2021',
#  '144648 ALLEN, KASSEEN F ECHC 06/29/2021',
#  '155564 ALLEN, TIFFANY M ECHC 04/12/2021',
#  '94012 AMAN, JOSHUA D ECHC 06/27/2021',
#  '60170 ANDREWS, NICOLE J ECHC 04/24/2021',
#  '1550 ARCARA, SHAWN ECCF 01/20/2021',
#  '69158 ARCHER, MARTELL ECHC 07/01/2021',
#  '84791 AULS, RAYMOND ECHC 06/03/2021',
#  '124759 AUSTIN, RASHAWN G ECHC 01/28/2021',
#  '150703 AYALA, MIKEL D ECCF 05/17/2021',
#  '90957 BAEZ, OSCAR J ECHC 06/22/2021',
#  '144717 BAILEY, JARELD D ECHC 03/18/2021',
#  '152772 BAKER, BRYCE J ECCF 12/04/2020',
#  '156189 BALD, EDWARD M ECHC 02/27/2021',
#  '45844 BARBER, CORELLIS C ECCF 06/02/2021',
#  '11444 BARBER, KEVIN ECCF 02/26/2020',
#  '99417 BARCLAY, BRANDON ECCF 09/24/2020',
#  '121931 BARCLAY, CHEMERE ECHC 04/29/2021',
#  '156058 BARKER, JOHN ECHC 11/27/2020',
#  '6400 BARKER, LLOYD ECHC 09/30/2020',
#  '60960 BARNES, BYRON K ECCF 03/13/2021',
#  '143728 BARNES, DONNELL A ECHC 06/30/2021',
#  '156210 BARNWELL, GAIL ECHC 03/12/2021',
#  '139480 BARNWELL, RICHARD ECCF 10/07/2020',
#  '99034 BARROWMAN, GLENN R ECHC 07/08/2021',
#  '110974 BASSETT, BRYAM ECHC 05/08/2019',
#  '140981 BASTEDO, ROBARE ECCF 02/15/2021',
#  '141722 BATES, MOULIK D ECHC 03/16/2021',
#  '156050 BATES, TONY M ECHC 04/01/2021',
#  'Page 1 of 16Wednesday, July 14, 2021  9:45:01 amCreated On: At:',
#  '',
#  'ICN # Inmate Name Facility Booking Date',
#  "Erie County Sheriff's Office ",
#  'Inmate Roster',
#  
#  '98513 WATKINS, CALVIN ECCF 04/16/2020',
#  '113171 WATSON, MICAH ECCF 12/10/2020',
#  '156097 WATSON, SIDNEY ECCF 12/30/2020',
#  '144317 WEATHERSPOON, LIMMIE R ECHC 04/18/2021',
#  '156316 WEBBER, ALBERT J ECCF 05/07/2021',
#  '156302 WEBSTER , KENNETH T ECHC 05/03/2021',
#  '154819 WELLS, DAJON ECCF 05/22/2021',
#  '143244 WERTS, CAMREN ECCF 05/30/2021',
#  '129847 WERTS, STEVEN M ECHC 06/05/2021',
#  '117804 WHALEN, MARK G ECHC 01/13/2021',
#  '141434 WHITE, DAVIEON L ECHC 05/23/2021',
#  '2893 WHITE, GARY E ECHC 07/10/2021',
#  '154135 WHITE, JUSTIN K ECHC 03/01/2021',
#  '49900 WHITE, REGINALD A ECHC 06/27/2021',
#  '102936 WHITE, SHANEESHA A ECHC 06/27/2021',
#  '138752 WHITE, TIFFANY ECHC 06/03/2021',
#  'Page 15 of 16Wednesday, July 14, 2021  9:45:01 amCreated On: At:',
#  '',
#  'ICN # Inmate Name Facility Booking Date',
#  "Erie County Sheriff's Office ",
#  'Inmate Roster',
#  '27065 WHITFIELD, JAMES ECHC 07/05/2021',
#  '145872 WHITFIELD, KYA S ECHC 06/21/2021',
#  '150613 WHITTAKER, DAQUAN J ECCF 05/06/2021',
#  '149101 WHITTAKER, TANJA M ECHC 12/01/2020',
#  '1007 WILEY, KURT R ECCF 09/17/2020',
#  '147398 WILKINS, ODELL M ECHC 11/25/2020',
#  '98502 WILLIAMS, ADAM W ECHC 02/25/2021',
#  '132212 WILLIAMS, BRANDON ECHC 09/16/2020',
#  '105145 WILLIAMS, DAVID A ECHC 07/03/2021',
#  '97828 WILLIAMS, DEREK A ECCF 02/22/2021',
#  '127328 WILLIAMS, DONTA J ECHC 10/30/2019',
#  '136026 WILLIAMS, KEIVON M ECCF 06/07/2021',
#  '3330 WILLIAMS, OTIS D ECHC 05/27/2021',
#  '62867 WILLIAMS, RALPH N ECHC 08/30/2020',
#  '150397 WILLIAMS, ROQUAN D ECCF 08/13/2020',
#  '155830 WILLIAMS, TALYN D ECHC 06/20/2020',
#  '10737 WILSON, DEANDRE L ECCF 10/09/2019',
#  '146071 WILSON, DWIGHT M ECHC 06/15/2021',
#  '154035 WILSON, GENILE ECHC 05/27/2021',
#  '140815 WILSON, JOSHUA E ECHC 07/10/2020',
#  '142516 WINKOWSKI, JACOB T ECHC 05/15/2021',
#  '80369 WOLFE, JAMES B ECHC 01/23/2021',
#  '127089 WOLFSON, BRIAN ECHC 06/30/2021',
#  '156294 WOOD, ALISIA S ECHC 04/28/2021',
#  '51921 WOOD, RICKY J ECHC 11/17/2020',
#  '13321 WOODS, RONALD ECCF 04/16/2021',
#  '88406 WORTHY, DEVINE ECHC 06/30/2021',
#  '36220 WOSILAIT, RONALD ECHC 04/21/2021',
#  '26982 WRIGHT, JAMES L ECHC 07/07/2021',
#  '156056 WRIGHT, RODERICK D ECCF 11/26/2020',
#  '34017 WYATT, DAVID ECHC 06/30/2021',
#  '128323 WYATT, JABREIL ECHC 10/25/2020',
#  '95694 YOUNG, DAVID ECHC 06/16/2021',
#  '87957 ZACCARIA, NICHOLAS E ECHC 02/27/2021',
#  '18303 ZANGHI, SANTINO J ECHC 05/24/2021',
#  '155109 ZARCONE, THOMAS E ECHC 06/27/2021',
#  '63815 ZIELINSKI, LARRY ECHC 07/06/2021',
#  '20740 ZIELINSKI, LAWRENCE T ECCF 11/04/2020',
#  '155732 ZUKIC, TRAVIS ECCF 03/01/2020',
#  ' 684Total in custody:',
#  'Page 16 of 16Wednesday, July 14, 2021  9:45:01 amCreated On: At:']

# %%
# pandas series and dataframes vs. python list vs. numpy arrays
inmates_pd = pd.Series(inmates_ls)
re_keep = r'^[0-9]+ [A-Z]+, [A-Z]+'
inmates_pd = inmates_pd[inmates_pd.str.contains(re_keep,regex=True)]

# %%
inmates_df
# Out:
# Empty DataFrame
# Columns: [ICN #, Inmate Name, Facility, Booking Date]
# Index: []

# %%
inmates_df['Facility'] = inmates_pd.str.rsplit(n=2, expand=True)[1]
inmates_df['Booking Date'] = inmates_pd.str.rsplit(n=2, expand=True)[2]
inmates_df['ICN #'] = inmates_pd.str.split(n=1, expand=True)[0]
inmates_df
# Out:
#       ICN # Inmate Name Facility Booking Date
# 0     70693         NaN     ECHC   04/30/2021
# 1    152645         NaN     ECCF   06/20/2021
# 2    144666         NaN     ECCF   06/17/2021
# 3    156374         NaN     ECHC   06/06/2021
# 4     57243         NaN     ECCF   11/02/2020
# ..      ...         ...      ...          ...
# 754   18303         NaN     ECHC   05/24/2021
# 755  155109         NaN     ECHC   06/27/2021
# 756   63815         NaN     ECHC   07/06/2021
# 757   20740         NaN     ECCF   11/04/2020
# 758  155732         NaN     ECCF   03/01/2020
#
# [669 rows x 4 columns]

# %%
#inmates_df['Inmate Name'].str.rsplit(n=2, expand=True)[0]
names = inmates_pd.str.rsplit(n=2, expand=True)
inmates_df['Inmate Name'] = names[0].str.split(n=1, expand=True)[1]
inmates_df
# Out:
#       ICN #            Inmate Name Facility Booking Date
# 0     70693      ABDALLAH, MICHAEL     ECHC   04/30/2021
# 1    152645             ABDI, ABDI     ECCF   06/20/2021
# 2    144666       ABDULLAH, DHAFIR     ECCF   06/17/2021
# 3    156374        ACEVEDO, CARLOS     ECHC   06/06/2021
# 4     57243       ACKER, RAYMOND P     ECCF   11/02/2020
# ..      ...                    ...      ...          ...
# 754   18303      ZANGHI, SANTINO J     ECHC   05/24/2021
# 755  155109      ZARCONE, THOMAS E     ECHC   06/27/2021
# 756   63815       ZIELINSKI, LARRY     ECHC   07/06/2021
# 757   20740  ZIELINSKI, LAWRENCE T     ECCF   11/04/2020
# 758  155732          ZUKIC, TRAVIS     ECCF   03/01/2020
#
# [669 rows x 4 columns]

# %%
inmates_df.to_csv('inmates_done.csv')

# %% [markdown]
# ## WHO resolutions
#
# Using [A74_R13-en.pdf](A74_R13-en.pdf), what ten member countries are given the highest assessments?
#
# * You might need to have two separate queries, and combine the results: that last page is pretty awful!
# * Always rename your columns
# * Double-check that your sorting looks right......
# * You can still get the answer even without perfectly clean data

# %%
import camelot
tables = camelot.read_pdf('A74_R13-en.pdf', flavor='stream', pages='1-6')
tables
# Out:
# <TableList n=6>

# %%
tables_pieces = [table.df.drop([0,1,2]) for table in tables[0:5]]
tables_pieces
# Out:
# [                                   0       1
#  3                        Afghanistan  0.0070
#  4                            Albania  0.0080
#  5                            Algeria  0.1380
#  6                            Andorra  0.0050
#  7                             Angola  0.0100
#  8                Antigua and Barbuda  0.0020
#  9                          Argentina  0.9151
#  10                           Armenia  0.0070
#  11                         Australia  2.2101
#  12                           Austria  0.6770
#  13                        Azerbaijan  0.0490
#  14                           Bahamas  0.0180
#  15                           Bahrain  0.0500
#  16                        Bangladesh  0.0100
#  17                          Barbados  0.0070
#  18                           Belarus  0.0490
#  19                           Belgium  0.8211
#  20                            Belize  0.0010
#  21                             Benin  0.0030
#  22                            Bhutan  0.0010
#  23  Bolivia (Plurinational State of)  0.0160,
#                                      0        1
#  3              Bosnia and Herzegovina   0.0120
#  4                            Botswana   0.0140
#  5                              Brazil   2.9482
#  6                   Brunei Darussalam   0.0250
#  7                            Bulgaria   0.0460
#  8                        Burkina Faso   0.0030
#  9                             Burundi   0.0010
#  10                         Cabo Verde   0.0010
#  11                           Cambodia   0.0060
#  12                           Cameroon   0.0130
#  13                             Canada   2.7342
#  14           Central African Republic   0.0010
#  15                               Chad   0.0040
#  16                              Chile   0.4070
#  17                              China  12.0058
#  18                           Colombia   0.2880
#  19                            Comoros   0.0010
#  20                              Congo   0.0060
#  21  Cook Islands (not a member of the
#  22                    United Nations)   0.0010
#  23                         Costa Rica   0.0620
#  24                      Côte d’Ivoire   0.0130
#  25                            Croatia   0.0770
#  26                               Cuba   0.0800
#  27                             Cyprus   0.0360
#  28                     Czech Republic   0.3110
#  29    Democratic People’s Republic of
#  30                              Korea   0.0060
#  31   Democratic Republic of the Congo   0.0100
#  32                            Denmark   0.5540
#  33                           Djibouti   0.0010
#  34                           Dominica   0.0010
#  35                 Dominican Republic   0.0530
#  36                            Ecuador   0.0800
#  37                              Egypt   0.1860
#  38                        El Salvador   0.0120
#  39                  Equatorial Guinea   0.0160
#  40                            Eritrea   0.0010
#  41                            Estonia   0.0390
#  42                           Eswatini   0.0020
#  43                           Ethiopia   0.0100
#  44                               Fiji   0.0030
#  45                            Finland   0.4210
#  46                             France   4.4273
#  47                              Gabon   0.0150,
#                                     0       1
#  3                             Gambia  0.0010
#  4                            Georgia  0.0080
#  5                            Germany  6.0904
#  6                              Ghana  0.0150
#  7                             Greece  0.3660
#  8                            Grenada  0.0010
#  9                          Guatemala  0.0360
#  10                            Guinea  0.0030
#  11                     Guinea-Bissau  0.0010
#  12                            Guyana  0.0020
#  13                             Haiti  0.0030
#  14                          Honduras  0.0090
#  15                           Hungary  0.2060
#  16                           Iceland  0.0280
#  17                             India  0.8341
#  18                         Indonesia  0.5430
#  19        Iran (Islamic Republic of)  0.3980
#  20                              Iraq  0.1290
#  21                           Ireland  0.3710
#  22                            Israel  0.4900
#  23                             Italy  3.3072
#  24                           Jamaica  0.0080
#  25                             Japan  8.5645
#  26                            Jordan  0.0210
#  27                        Kazakhstan  0.1780
#  28                             Kenya  0.0240
#  29                          Kiribati  0.0010
#  30                            Kuwait  0.2520
#  31                        Kyrgyzstan  0.0020
#  32  Lao People’s Democratic Republic  0.0050
#  33                            Latvia  0.0470
#  34                           Lebanon  0.0470
#  35                           Lesotho  0.0010
#  36                           Liberia  0.0010
#  37                             Libya  0.0300
#  38                         Lithuania  0.0710
#  39                        Luxembourg  0.0670
#  40                        Madagascar  0.0040
#  41                            Malawi  0.0020
#  42                          Malaysia  0.3410
#  43                          Maldives  0.0040
#  44                              Mali  0.0040
#  45                             Malta  0.0170
#  46                  Marshall Islands  0.0010,
#                                     0       1
#  3                         Mauritania  0.0020
#  4                          Mauritius  0.0110
#  5                             Mexico  1.2921
#  6   Micronesia (Federated States of)  0.0010
#  7                             Monaco  0.0110
#  8                           Mongolia  0.0050
#  9                         Montenegro  0.0040
#  10                           Morocco  0.0550
#  11                        Mozambique  0.0040
#  12                           Myanmar  0.0100
#  13                           Namibia  0.0090
#  14                             Nauru  0.0010
#  15                             Nepal  0.0070
#  16                       Netherlands  1.3561
#  17                       New Zealand  0.2910
#  18                         Nicaragua  0.0050
#  19                             Niger  0.0020
#  20                           Nigeria  0.2500
#  21  Niue (not a member of the United
#  22                          Nations)  0.0010
#  23                   North Macedonia  0.0070
#  24                            Norway  0.7540
#  25                              Oman  0.1150
#  26                          Pakistan  0.1150
#  27                             Palau  0.0010
#  28                            Panama  0.0450
#  29                  Papua New Guinea  0.0100
#  30                          Paraguay  0.0160
#  31                              Peru  0.1520
#  32                       Philippines  0.2050
#  33                            Poland  0.8021
#  34                          Portugal  0.3500
#  35  Puerto Rico (not a member of the
#  36                   United Nations)  0.0010
#  37                             Qatar  0.2820
#  38                 Republic of Korea  2.2671
#  39               Republic of Moldova  0.0030
#  40                           Romania  0.1980
#  41                Russian Federation  2.4052
#  42                            Rwanda  0.0030
#  43             Saint Kitts and Nevis  0.0010
#  44                       Saint Lucia  0.0010
#  45  Saint Vincent and the Grenadines  0.0010
#  46                             Samoa  0.0010
#  47                        San Marino  0.0020,
#                                        0        1
#  3                 Sao Tome and Principe   0.0010
#  4                          Saudi Arabia   1.1721
#  5                               Senegal   0.0070
#  6                                Serbia   0.0280
#  7                            Seychelles   0.0020
#  8                          Sierra Leone   0.0010
#  9                             Singapore   0.4850
#  10                             Slovakia   0.1530
#  11                             Slovenia   0.0760
#  12                      Solomon Islands   0.0010
#  13                              Somalia   0.0010
#  14                         South Africa   0.2720
#  15                          South Sudan   0.0060
#  16                                Spain   2.1461
#  17                            Sri Lanka   0.0440
#  18                                Sudan   0.0100
#  19                             Suriname   0.0050
#  20                               Sweden   0.9061
#  21                          Switzerland   1.1511
#  22                 Syrian Arab Republic   0.0110
#  23                           Tajikistan   0.0040
#  24                             Thailand   0.3070
#  25                          Timor-Leste   0.0020
#  26                                 Togo   0.0020
#  27  Tokelau (not a member of the United
#  28                             Nations)   0.0010
#  29                                Tonga   0.0010
#  30                  Trinidad and Tobago   0.0400
#  31                              Tunisia   0.0250
#  32                               Turkey   1.3711
#  33                         Turkmenistan   0.0330
#  34                               Tuvalu   0.0010
#  35                               Uganda   0.0080
#  36                              Ukraine   0.0570
#  37                 United Arab Emirates   0.6160
#  38  United Kingdom of Great Britain and
#  39                     Northern Ireland   4.5673
#  40          United Republic of Tanzania   0.0100
#  41             United States of America  22.0000
#  42                              Uruguay   0.0870
#  43                           Uzbekistan   0.0320
#  44                              Vanuatu   0.0010
#  45   Venezuela (Bolivarian Republic of)   0.7280
#  46                             Viet Nam   0.0770
#  47                                Yemen   0.0100]

# %%
# pd.DataFrame([tables[0:4] + last_table])
last_table = tables[5].df.drop(columns=[0,2,4]).drop([0,1,2,3,6,7,8,9])
last_table.columns = [0,1]
last_table
# Out:
#           0       1
# 4    Zambia  0.0090
# 5  Zimbabwe  0.0050

# %%
scales = pd.concat(tables_pieces, ignore_index=True).append(last_table)
scales.columns = ['Member','Percent']
scales = scales.reset_index()
scales = scales.drop(columns='index').set_index('Member')
scales.tail(10)
# Out:
#                                     Percent
# Member
# United Republic of Tanzania          0.0100
# United States of America            22.0000
# Uruguay                              0.0870
# Uzbekistan                           0.0320
# Vanuatu                              0.0010
# Venezuela (Bolivarian Republic of)   0.7280
# Viet Nam                             0.0770
# Yemen                                0.0100
# Zambia                               0.0090
# Zimbabwe                             0.0050

# %%
scales['Percent'].sort_values(ascending=False).head(10)
# Out:
# Member
# Japan                        8.5645
# Germany                      6.0904
# Northern Ireland             4.5673
# France                       4.4273
# Italy                        3.3072
# United States of America    22.0000
# Brazil                       2.9482
# Canada                       2.7342
# Russian Federation           2.4052
# Republic of Korea            2.2671
# Name: Percent, dtype: object

# %% [markdown]
# ## The Avengers
#
# Using [THE_AVENGERS.pdf](THE_AVENGERS.pdf), approximately how many lines does Captain America have as compared to Thor and Iron Man?
#
# * Character names only: we're only counting `IRON MAN` as Iron Man, not `TONY`.
# * Your new best friend might be `\n`
# * Look up `.count` for strings

# %% [markdown]
# ## COVID data
#
# Using [covidweekly2721.pdf](covidweekly2721.pdf), what's the total number of tests performed in Minnesota? Use the Laboratory Test Rates by County of Residence chart.
#
# * You COULD pull both tables separately OR you could pull them both at once and split them in pandas.
# * Remember you can do things like `df[['name','age']]` to ask for multiple columns

# %% [markdown]
# ## Theme Parks
#
# Using [2019-Theme-Index-web-1.pdf](2019-Theme-Index-web-1.pdf), save a CSV of the top 10 theme park groups worldwide.
#
# * You can clean the results or you can restrict the area the table is pulled from, up to you

# %% [markdown]
# ## Hunting licenses
#
# Using [US_Fish_and_Wildlife_Service_2021.pdf](US_Fish_and_Wildlife_Service_2021.pdf) and [a CSV of state populations](http://goodcsv.com/geography/us-states-territories/), find the states with the highest per-capita hunting license holders.
